# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/content/Live.csv')
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                           status_id status_type status_published  \
# 0  246675545449582_1649696485147474       video   4/22/2018 6:00
# 1  246675545449582_1649426988507757       photo  4/21/2018 22:45
# 2  246675545449582_1648730588577397       video   4/21/2018 6:17
# 3  246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4  246675545449582_1645700502213739       photo   4/18/2018 3:22
#
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0            529           512         262        432         92         3
# 1            150             0           0        150          0         0
# 2            227           236          57        204         21         1
# 3            111             0           0        111          0         0
# 4            213             0           0        204          9         0
#
#    num_hahas  num_sads  num_angrys  Column1  Column2  Column3  Column4
# ...

# %%
df.tail()
# Out:
#                               status_id status_type status_published  \
# 7045  1050855161656896_1061863470556065       photo   9/24/2016 2:58
# 7046  1050855161656896_1061334757275603       photo  9/23/2016 11:19
# 7047  1050855161656896_1060126464063099       photo  9/21/2016 23:03
# 7048  1050855161656896_1058663487542730       photo   9/20/2016 0:43
# 7049  1050855161656896_1050858841656528       photo  9/10/2016 10:30
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 7045             89             0           0         89          0         0
# 7046             16             0           0         14          1         0
# 7047              2             0           0          1          1         0
# 7048            351            12          22        349          2         0
# 7049             17             0           0         17          0         0
#
#       num_hahas  num_sads  num_angrys  Column1  Column2  Column3  Column4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   status_id         7050 non-null   object
#  1   status_type       7050 non-null   object
#  2   status_published  7050 non-null   object
#  3   num_reactions     7050 non-null   int64
#  4   num_comments      7050 non-null   int64
#  5   num_shares        7050 non-null   int64
#  6   num_likes         7050 non-null   int64
#  7   num_loves         7050 non-null   int64
#  8   num_wows          7050 non-null   int64
#  9   num_hahas         7050 non-null   int64
#  10  num_sads          7050 non-null   int64
#  11  num_angrys        7050 non-null   int64
#  12  Column1           0 non-null      float64
#  13  Column2           0 non-null      float64
#  14  Column3           0 non-null      float64
#  15  Column4           0 non-null      float64
# ...

# %%
df.describe()
# Out:
#        num_reactions  num_comments   num_shares    num_likes    num_loves  \
# count    7050.000000   7050.000000  7050.000000  7050.000000  7050.000000
# mean      230.117163    224.356028    40.022553   215.043121    12.728652
# std       462.625309    889.636820   131.599965   449.472357    39.972930
# min         0.000000      0.000000     0.000000     0.000000     0.000000
# 25%        17.000000      0.000000     0.000000    17.000000     0.000000
# 50%        59.500000      4.000000     0.000000    58.000000     0.000000
# 75%       219.000000     23.000000     4.000000   184.750000     3.000000
# max      4710.000000  20990.000000  3424.000000  4710.000000   657.000000
#
#           num_wows    num_hahas     num_sads   num_angrys  Column1  Column2  \
# count  7050.000000  7050.000000  7050.000000  7050.000000      0.0      0.0
# mean      1.289362     0.696454     0.243688     0.113191      NaN      NaN
# ...

# %%
(df.describe().T)
# Out:
#                 count        mean         std  min   25%   50%     75%  \
# num_reactions  7050.0  230.117163  462.625309  0.0  17.0  59.5  219.00
# num_comments   7050.0  224.356028  889.636820  0.0   0.0   4.0   23.00
# num_shares     7050.0   40.022553  131.599965  0.0   0.0   0.0    4.00
# num_likes      7050.0  215.043121  449.472357  0.0  17.0  58.0  184.75
# num_loves      7050.0   12.728652   39.972930  0.0   0.0   0.0    3.00
# num_wows       7050.0    1.289362    8.719650  0.0   0.0   0.0    0.00
# num_hahas      7050.0    0.696454    3.957183  0.0   0.0   0.0    0.00
# num_sads       7050.0    0.243688    1.597156  0.0   0.0   0.0    0.00
# num_angrys     7050.0    0.113191    0.726812  0.0   0.0   0.0    0.00
# Column1           0.0         NaN         NaN  NaN   NaN   NaN     NaN
# Column2           0.0         NaN         NaN  NaN   NaN   NaN     NaN
# Column3           0.0         NaN         NaN  NaN   NaN   NaN     NaN
# ...

# %%
df.isnull()
# Out:
#       status_id  status_type  status_published  num_reactions  num_comments  \
# 0         False        False             False          False         False
# 1         False        False             False          False         False
# 2         False        False             False          False         False
# 3         False        False             False          False         False
# 4         False        False             False          False         False
# ...         ...          ...               ...            ...           ...
# 7045      False        False             False          False         False
# 7046      False        False             False          False         False
# 7047      False        False             False          False         False
# 7048      False        False             False          False         False
# 7049      False        False             False          False         False
#
# ...

# %%
df.isnull().sum()
# Out:
# status_id              0
# status_type            0
# status_published       0
# num_reactions          0
# num_comments           0
# num_shares             0
# num_likes              0
# num_loves              0
# num_wows               0
# num_hahas              0
# num_sads               0
# num_angrys             0
# Column1             7050
# Column2             7050
# Column3             7050
# Column4             7050
# dtype: int64

# %%
df.shape
# Out:
# (7050, 16)

# %%
df['status_id'].unique()
(len(df['status_id'].unique()))
# Out:
# 6997

# %%
df['status_published'].unique()
(len(df['status_published'].unique()))
# Out:
# 6913

# %%
df.drop(['status_published','status_id','Column1','Column2','Column3','Column4'],axis=1,inplace=True)

# %%
import matplotlib.pyplot as plt

# %%
x = df['num_reactions']
plt.plot(x)
plt.xlabel('num_reactions')
# Out:
# Text(0.5, 0, 'num_reactions')

# %%
x = df['status_type']
y=df['num_comments']
plt.bar(x,y)
plt.xlabel('status_type')
plt.ylabel('num_comments')
# Out:
# Text(0, 0.5, 'num_comments')

# %%
x = df['status_type']
y = df['num_reactions']
plt.scatter(x,y)
plt.xlabel('')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
plt.pie(x=df['num_angrys'])
plt.xlabel('num_angrys')
# Out:
# Text(0.5, 0, 'num_angrys')

# %%
plt.hist(x=df['num_loves'])
plt.xlabel('num_loves')
# Out:
# Text(0.5, 0, 'num_loves')

# %%
import seaborn as sns

# %%
sns.lineplot(x=df['num_shares'],y=df['num_likes'])
# Out:
# <Axes: xlabel='num_shares', ylabel='num_likes'>

# %%
sns.countplot(x=df['num_wows'])
# Out:
# <Axes: xlabel='num_wows', ylabel='count'>

# %%
sns.barplot(x=df['num_sads'],y=df['num_angrys'])
# Out:
# <Axes: xlabel='num_sads', ylabel='num_angrys'>

# %%
sns.scatterplot(x=df['status_type'],y=df['num_angrys'])
# Out:
# <Axes: xlabel='status_type', ylabel='num_angrys'>

# %%
sns.boxplot(x=df['num_loves'])
# Out:
# <Axes: xlabel='num_loves'>

# %%
sns.distplot(x=df['num_hahas'])
# Out:
# <ipython-input-80-b8e6335b5857>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['num_hahas'])
# <Axes: ylabel='Density'>

# %%
sns.pairplot(df,hue='status_type')

# %%
cate = []
for i in df.columns:
  if(df[i].dtypes=="object"):
    cate.append(i)
    print(i)
# Out:
# status_type

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lbl_encoder = LabelEncoder()
for i in cate:
  df[i]=df[[i]].apply(lbl_encoder.fit_transform)

# %%
x=df
x
# Out:
#       status_type  num_reactions  num_comments  num_shares  num_likes  \
# 0               3            529           512         262        432
# 1               1            150             0           0        150
# 2               3            227           236          57        204
# 3               1            111             0           0        111
# 4               1            213             0           0        204
# ...           ...            ...           ...         ...        ...
# 7045            1             89             0           0         89
# 7046            1             16             0           0         14
# 7047            1              2             0           0          1
# 7048            1            351            12          22        349
# 7049            1             17             0           0         17
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys
# 0            92         3          1         1           0
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
a = MinMaxScaler()

# %%
x=a.fit_transform(x)
x
# Out:
# array([[1.00000000e+00, 1.12314225e-01, 2.43925679e-02, ...,
#         6.36942675e-03, 1.96078431e-02, 0.00000000e+00],
#        [3.33333333e-01, 3.18471338e-02, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 4.81953291e-02, 1.12434493e-02, ...,
#         6.36942675e-03, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [3.33333333e-01, 4.24628450e-04, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [3.33333333e-01, 7.45222930e-02, 5.71700810e-04, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [3.33333333e-01, 3.60934183e-03, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %%
from sklearn.cluster import KMeans
em = []
for i in range(1,11):
  kmeans = KMeans(n_clusters=i, init="k-means++",max_iter=300,n_init=10,random_state=0)
  kmeans.fit(x)
  em.append(kmeans.inertia_)
plt.plot(range(1,11),em)
plt.title('elbow method')
plt.xlabel('clusters')
plt.ylabel('kmeans inertia')
plt.show()

# %%
kmeans = KMeans(n_clusters=5,init="k-means++",random_state=0)
y_kmeans=kmeans.fit_predict(x)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
kmeans.inertia_
# Out:
# 96.24989550305185

# %%
centroid = kmeans.cluster_centers_
centroid
# Out:
# array([[3.29218107e-01, 1.95208308e-02, 6.50434801e-04, 5.35895678e-04,
#         1.90498951e-02, 1.93878780e-03, 2.03323180e-03, 1.16873045e-03,
#         2.84790750e-03, 1.52271183e-03],
#        [1.00000000e+00, 3.70762995e-02, 2.38485859e-02, 2.47674444e-02,
#         3.13111517e-02, 3.78268104e-02, 2.46348376e-03, 7.32261369e-03,
#         5.97833539e-03, 5.20339875e-03],
#        [3.58565737e-01, 4.09777451e-01, 3.05229772e-03, 4.40876680e-03,
#         4.08225273e-01, 6.12466420e-03, 1.07483734e-02, 1.59870074e-03,
#         8.59307867e-04, 1.28518185e-04],
#        [6.66666667e-01, 6.13982227e-02, 1.38161029e-03, 6.93414573e-04,
#         6.07663654e-02, 2.34234727e-03, 3.13401973e-03, 7.43735459e-04,
#         8.27756252e-03, 8.69229283e-04],
#        [1.00000000e+00, 3.22288500e-01, 1.07331534e-01, 1.36127491e-01,
#         2.81808378e-01, 2.38723394e-01, 8.07925089e-02, 5.33818623e-02,
#         3.23685030e-02, 4.21573647e-02]])

# %%
labels=kmeans.labels_
print(labels)
# Out:
# [1 0 1 ... 0 0 0]

# %%
y_kmeans
# Out:
# array([1, 0, 1, ..., 0, 0, 0], dtype=int32)

# %%
plt.figure(figsize=(15,7))
plt.scatter(x[y_kmeans == 0,0], x[y_kmeans == 0,1],color="green",label="Cluster 1",s=50)
plt.scatter(x[y_kmeans == 1,0], x[y_kmeans == 1,1],color="yellow",label="Cluster 2",s=50)
plt.scatter(x[y_kmeans == 2,0], x[y_kmeans == 2,1],color="red",label="Cluster 3",s=50)
plt.scatter(x[y_kmeans == 3,0], x[y_kmeans == 3,1],color="orange",label="Cluster 4",s=50)
plt.scatter(x[y_kmeans == 4,0], x[y_kmeans == 4,1],color="black",label="Cluster 4",s=50)
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],color='blue',label='Centroids',s=300,marker=',')
plt.grid(False)
plt.title('clusters of celebraties')
plt.xlabel('s')
plt.ylabel('p')
plt.legend()
plt.show()
